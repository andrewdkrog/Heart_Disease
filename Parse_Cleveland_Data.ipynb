# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('./Cleveland_Full_Data.csv')

# %%
df.iloc[0:10,:]
# Out:
#     Col1  Col2   Col3   Col4  Col5  Col6  Col7  Col8  Unnamed: 8  Unnamed: 9  \
# 0    1.0   0.0   63.0    1.0    -9  -9.0  -9.0   NaN         NaN         NaN
# 1   -9.0   1.0  145.0    1.0   233  -9.0  50.0  20.0         NaN         NaN
# 2    1.0  -9.0    1.0    2.0     2   3.0  81.0   0.0         NaN         NaN
# 3    0.0   0.0    0.0    0.0     1  10.5   6.0  13.0         NaN         NaN
# 4  150.0  60.0  190.0   90.0   145  85.0   0.0   0.0         NaN         NaN
# 5    2.3   3.0   -9.0  172.0     0  -9.0  -9.0  -9.0         NaN         NaN
# 6   -9.0  -9.0   -9.0    6.0    -9  -9.0  -9.0   2.0         NaN         NaN
# 7   16.0  81.0    0.0    1.0     1   1.0  -9.0   1.0         NaN         NaN
# 8   -9.0   1.0   -9.0    1.0     1   1.0   1.0   1.0         NaN         NaN
# 9    1.0   1.0   -9.0   -9.0  name   NaN   NaN   NaN         NaN         NaN
#
#    Unnamed: 10  Unnamed: 11  Unnamed: 12  Unnamed: 13  Unnamed: 14  \
# ...

# %%
df = df.iloc[:, 0:8]
df.iloc[0:10,:]
# Out:
#     Col1  Col2   Col3   Col4  Col5  Col6  Col7  Col8
# 0    1.0   0.0   63.0    1.0    -9  -9.0  -9.0   NaN
# 1   -9.0   1.0  145.0    1.0   233  -9.0  50.0  20.0
# 2    1.0  -9.0    1.0    2.0     2   3.0  81.0   0.0
# 3    0.0   0.0    0.0    0.0     1  10.5   6.0  13.0
# 4  150.0  60.0  190.0   90.0   145  85.0   0.0   0.0
# 5    2.3   3.0   -9.0  172.0     0  -9.0  -9.0  -9.0
# 6   -9.0  -9.0   -9.0    6.0    -9  -9.0  -9.0   2.0
# 7   16.0  81.0    0.0    1.0     1   1.0  -9.0   1.0
# 8   -9.0   1.0   -9.0    1.0     1   1.0   1.0   1.0
# 9    1.0   1.0   -9.0   -9.0  name   NaN   NaN   NaN

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
set1 = []

for j in range(282):
    set1.append(df.iloc[j*10,:])

# %%
print(set1)
# Out:
# [Col1      1
# Col2      0
# Col3     63
# Col4      1
# Col5     -9
# Col6     -9
# Col7     -9
# Col8    NaN
# Name: 0, dtype: object, Col1      2
# Col2      0
# Col3     67
# Col4      1
# Col5     -9
# Col6     -9
# Col7     -9
# Col8    NaN
# Name: 10, dtype: object, Col1      3
# Col2      0
# Col3     67
# Col4      1
# Col5     -9
# Col6     -9
# Col7     -9
# Col8    NaN
# Name: 20, dtype: object, Col1      4
# Col2      0
# Col3     37
# Col4      1
# Col5     -9
# Col6     -9
# Col7     -9
# Col8    NaN
# Name: 30, dtype: object, Col1      6
# Col2      0
# Col3     41
# Col4      0
# Col5     -9
# Col6     -9
# Col7     -9
# Col8    NaN
# Name: 40, dtype: object, Col1      7
# Col2      0
# Col3     56
# Col4      1
# Col5     -9
# Col6     -9
# Col7     -9
# Col8    NaN
# Name: 50, dtype: object, Col1      8
# Col2      0
# Col3     62
# Col4      0
# Col5     -9
# Col6     -9
# Col7     -9
# Col8    NaN
# Name: 60, dtype: object, Col1      9
# Col2      0
# ...
